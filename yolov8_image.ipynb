# %% [markdown]
# <a href="https://colab.research.google.com/github/seungheon999/yolov8/blob/main/yolov8_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. YOLOv8 설치

# %%
# !pip install ultralytics

# %% [markdown]
# 2. 필요한 라이브러리 임포트

# %%
from ultralytics import YOLO
from PIL import Image
import requests
import io

# %% [markdown]
# 3. 사전 훈련된 YOLOv8 모델 로드

# %%
model = YOLO('yolov8x.pt')
# Out:
# ...
# 100%|██████████| 131M/131M [00:01<00:00, 120MB/s]

# %% [markdown]
# 4. 인터넷에서 도로 이미지 가져오기

# %%
url = "https://www.chosun.com/resizer/v2/GM2JXZGOP5DPNOFN6DSS32ECEE.jpg?auth=745d3fef479bac83fb073e1fcd5da038c3103f2d97694f0e27b06477e4798667&width=616" # 원하는 도로 이미지 URL로 변경하세요
response = requests.get(url)
img = Image.open(io.BytesIO(response.content))

# %% [markdown]
# 5. 객체 감지 실행

# %%
results = model(img)
# Out:
# 0: 480x640 2 persons, 6 cars, 8 traffic lights, 78.6ms
# Speed: 2.1ms preprocess, 78.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# 6. 결과 시각화

# %%
results[0].plot()
# Out:
# array([[[146, 142, 131],
#         [151, 147, 136],
#         [156, 152, 141],
#         ...,
#         [ 42,  47,  48],
#         [ 59,  64,  65],
#         [ 77,  82,  83]],
#
#        [[146, 142, 131],
#         [149, 145, 134],
#         [152, 148, 137],
#         ...,
#         [ 68,  73,  74],
#         [ 65,  70,  71],
#         [ 47,  52,  53]],
#
#        [[147, 143, 132],
#         [147, 143, 132],
#         [148, 144, 133],
#         ...,
#         [ 79,  84,  85],
#         [ 69,  74,  75],
#         [ 34,  39,  40]],
#
#        ...,
#
#        [[216, 224, 231],
#         [214, 222, 229],
#         [211, 219, 226],
#         ...,
#         [133, 124, 120],
#         [132, 123, 119],
#         [133, 124, 120]],
#
#        [[203, 211, 218],
#         [202, 210, 217],
#         [200, 208, 215],
#         ...,
#         [194, 188, 183],
#         [193, 187, 182],
#         [194, 188, 183]],
#
#        [[199, 207, 214],
#         [199, 207, 214],
#         [198, 206, 213],
# ...
